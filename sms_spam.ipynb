# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/SPAM text message 20170820 - Data.csv')
df
# Out:
#      Category                                            Message
# 0         ham  Go until jurong point, crazy.. Available only ...
# 1         ham                      Ok lar... Joking wif u oni...
# 2        spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3         ham  U dun say so early hor... U c already then say...
# 4         ham  Nah I don't think he goes to usf, he lives aro...
# ...       ...                                                ...
# 5567     spam  This is the 2nd time we have tried 2 contact u...
# 5568      ham               Will ü b going to esplanade fr home?
# 5569      ham  Pity, * was in mood for that. So...any other s...
# 5570      ham  The guy did some bitching but I acted like i'd...
# 5571      ham                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Category  5572 non-null   object
#  1   Message   5572 non-null   object
# dtypes: object(2)
# memory usage: 87.2+ KB

# %%
df.isnull().sum()
# Out:
# Category    0
# Message     0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
encoded_label = encoder.fit_transform(df['Category'])
df['Category'] = encoded_label
df
# Out:
#       Category                                            Message
# 0            0  Go until jurong point, crazy.. Available only ...
# 1            0                      Ok lar... Joking wif u oni...
# 2            1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3            0  U dun say so early hor... U c already then say...
# 4            0  Nah I don't think he goes to usf, he lives aro...
# ...        ...                                                ...
# 5567         1  This is the 2nd time we have tried 2 contact u...
# 5568         0               Will ü b going to esplanade fr home?
# 5569         0  Pity, * was in mood for that. So...any other s...
# 5570         0  The guy did some bitching but I acted like i'd...
# 5571         0                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %%
df.drop_duplicates(keep= 'first',inplace=True)
df
# Out:
#       Category                                            Message
# 0            0  Go until jurong point, crazy.. Available only ...
# 1            0                      Ok lar... Joking wif u oni...
# 2            1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3            0  U dun say so early hor... U c already then say...
# 4            0  Nah I don't think he goes to usf, he lives aro...
# ...        ...                                                ...
# 5567         1  This is the 2nd time we have tried 2 contact u...
# 5568         0               Will ü b going to esplanade fr home?
# 5569         0  Pity, * was in mood for that. So...any other s...
# 5570         0  The guy did some bitching but I acted like i'd...
# 5571         0                         Rofl. Its true to its name
#
# [5157 rows x 2 columns]

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.Category.value_counts().plot.pie(figsize=(5,5),explode=[0,0.1],autopct='%1.2f%%',labels=['Ham','Spam'])
# Out:
# <Axes: ylabel='count'>

# %%
import nltk

# %%
nltk.download('punkt')
nltk.download('punkt_tab')
from nltk.corpus import stopwords
import string
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
df['num-of-character']=df['Message'].apply(len)
df.head()
# Out:
#    Category                                            Message  \
# 0         0  Go until jurong point, crazy.. Available only ...
# 1         0                      Ok lar... Joking wif u oni...
# 2         1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3         0  U dun say so early hor... U c already then say...
# 4         0  Nah I don't think he goes to usf, he lives aro...
#
#    num-of-character
# 0               111
# 1                29
# 2               155
# 3                49
# 4                61

# %%
df['num-of-words'] = df['Message'].apply(lambda x: len(nltk.word_tokenize(x)))
df.head()
# Out:
#    Category                                            Message  \
# 0         0  Go until jurong point, crazy.. Available only ...
# 1         0                      Ok lar... Joking wif u oni...
# 2         1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3         0  U dun say so early hor... U c already then say...
# 4         0  Nah I don't think he goes to usf, he lives aro...
#
#    num-of-character  num-of-words
# 0               111            24
# 1                29             8
# 2               155            37
# 3                49            13
# 4                61            15

# %%
df['num-of-sentences']=df['Message'].apply(lambda x:len(nltk.sent_tokenize(x)))
df.head()
# Out:
#    Category                                            Message  \
# 0         0  Go until jurong point, crazy.. Available only ...
# 1         0                      Ok lar... Joking wif u oni...
# 2         1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3         0  U dun say so early hor... U c already then say...
# 4         0  Nah I don't think he goes to usf, he lives aro...
#
#    num-of-character  num-of-words  num-of-sentences
# 0               111            24                 2
# 1                29             8                 2
# 2               155            37                 2
# 3                49            13                 1
# 4                61            15                 1

# %%
df[['num-of-character','num-of-words','num-of-sentences']].describe()
# Out:
#        num-of-character  num-of-words  num-of-sentences
# count       5157.000000   5157.000000       5157.000000
# mean          79.103936     18.560403          1.969750
# std           58.382922     13.405970          1.455526
# min            2.000000      1.000000          1.000000
# 25%           36.000000      9.000000          1.000000
# 50%           61.000000     15.000000          1.000000
# 75%          118.000000     26.000000          2.000000
# max          910.000000    220.000000         38.000000

# %%
df[df['Category']== 0][['num-of-character','num-of-words','num-of-sentences']].describe()
# Out:
#        num-of-character  num-of-words  num-of-sentences
# count       4516.000000   4516.000000       4516.000000
# mean          70.869353     17.267715          1.827724
# std           56.708301     13.588065          1.394338
# min            2.000000      1.000000          1.000000
# 25%           34.000000      8.000000          1.000000
# 50%           53.000000     13.000000          1.000000
# 75%           91.000000     22.000000          2.000000
# max          910.000000    220.000000         38.000000

# %%
df[df['Category']== 1][['num-of-character','num-of-words','num-of-sentences']].describe()
# Out:
#        num-of-character  num-of-words  num-of-sentences
# count        641.000000    641.000000        641.000000
# mean         137.118565     27.667707          2.970359
# std           30.399707      7.103501          1.485575
# min            7.000000      2.000000          1.000000
# 25%          130.000000     25.000000          2.000000
# 50%          148.000000     29.000000          3.000000
# 75%          157.000000     32.000000          4.000000
# max          223.000000     46.000000          9.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.histplot(df[df['Category']==0]['num-of-character'])
sns.histplot(df[df['Category']==1]['num-of-character'],color='red')
# Out:
# <Axes: xlabel='num-of-character', ylabel='Count'>

# %%
plt.figure(figsize=(10,8))
sns.histplot(df[df['Category']==0]['num-of-words'])
sns.histplot(df[df['Category']==1]['num-of-words'],color='red')
# Out:
# <Axes: xlabel='num-of-words', ylabel='Count'>

# %%
sns.heatmap(df[['Category', 'num-of-character', 'num-of-words', 'num-of-sentences']].corr(),annot=True)
# Out:
# <Axes: >

# %%
def transform_text(Message):
    Message = Message.lower()
    Message = nltk.word_tokenize(Message)

    y = []
    for i in Message:
        if i.isalnum():
            y.append(i)

    Message = y[:]
    y.clear()
    for i in Message:
        if i not in stopwords.words('english') and i not in string.punctuation:
            y.append(i)

    Message = y[:]
    y.clear()
    for i in Message:
        y.append(ps.stem(i))

    return " ".join(y)

# %%
df.Message[6]
# Out:
# 'Even my brother is not like to speak with me. They treat me like aids patent.'

# %%
transform_text('Even my brother is not like to speak with me. They treat me like aids patent.')
# Out:
# 'even brother like speak treat like aid patent'

# %%
df['transformed_text'] = df['Message'].apply(transform_text)

# %%
df
# Out:
#       Category                                            Message  \
# 0            0  Go until jurong point, crazy.. Available only ...
# 1            0                      Ok lar... Joking wif u oni...
# 2            1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3            0  U dun say so early hor... U c already then say...
# 4            0  Nah I don't think he goes to usf, he lives aro...
# ...        ...                                                ...
# 5567         1  This is the 2nd time we have tried 2 contact u...
# 5568         0               Will ü b going to esplanade fr home?
# 5569         0  Pity, * was in mood for that. So...any other s...
# 5570         0  The guy did some bitching but I acted like i'd...
# 5571         0                         Rofl. Its true to its name
#
#       num-of-character  num-of-words  num-of-sentences  \
# 0                  111            24                 2
# 1                   29             8                 2
# ...

# %%
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()
ps.stem('loving')
# Out:
# 'love'

# %%
df['transformed_text'] = df['Message'].apply(transform_text)

# %%
df.head()
# Out:
#    Category                                            Message  \
# 0         0  Go until jurong point, crazy.. Available only ...
# 1         0                      Ok lar... Joking wif u oni...
# 2         1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3         0  U dun say so early hor... U c already then say...
# 4         0  Nah I don't think he goes to usf, he lives aro...
#
#    num-of-character  num-of-words  num-of-sentences  \
# 0               111            24                 2
# 1                29             8                 2
# 2               155            37                 2
# 3                49            13                 1
# 4                61            15                 1
#
#                                     transformed_text
# 0  go jurong point crazi avail bugi n great world...
# 1                              ok lar joke wif u oni
# 2  free entri 2 wkli comp win fa cup final tkt 21...
# 3                u dun say earli hor u c alreadi say
# ...

# %%
from wordcloud import WordCloud
wc = WordCloud(width=500,height=500,min_font_size=10,background_color='white')

# %%
spam_wc = wc.generate(df[df['Category'] == 1]['transformed_text'].str.cat(sep=" "))

# %%
plt.figure(figsize=(15,6))
plt.imshow(spam_wc)

# %%
ham_wc = wc.generate(df[df['Category'] == 0]['transformed_text'].str.cat(sep=" "))

# %%
plt.figure(figsize=(15,6))
plt.imshow(ham_wc)

# %%
df.head()
# Out:
#    Category                                            Message  \
# 0         0  Go until jurong point, crazy.. Available only ...
# 1         0                      Ok lar... Joking wif u oni...
# 2         1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3         0  U dun say so early hor... U c already then say...
# 4         0  Nah I don't think he goes to usf, he lives aro...
#
#    num-of-character  num-of-words  num-of-sentences  \
# 0               111            24                 2
# 1                29             8                 2
# 2               155            37                 2
# 3                49            13                 1
# 4                61            15                 1
#
#                                     transformed_text
# 0  go jurong point crazi avail bugi n great world...
# 1                              ok lar joke wif u oni
# 2  free entri 2 wkli comp win fa cup final tkt 21...
# 3                u dun say earli hor u c alreadi say
# ...

# %%
spam_corpus = []
for msg in df[df['Category'] == 1]['transformed_text'].tolist():
    for word in msg.split():
        spam_corpus.append(word)

# %%
len(spam_corpus)
# Out:
# 9781

# %%
from collections import Counter
sns.barplot(x=pd.DataFrame(Counter(spam_corpus).most_common(30))[0], y=pd.DataFrame(Counter(spam_corpus).most_common(30))[1])
plt.xticks(rotation='vertical')
plt.show()

# %%
ham_corpus = []
for msg in df[df['Category'] == 0]['transformed_text'].tolist():
    for word in msg.split():
        ham_corpus.append(word)

# %%
len(ham_corpus)
# Out:
# 35940

# %%
from collections import Counter
sns.barplot(x=pd.DataFrame(Counter(ham_corpus).most_common(30))[0],y=pd.DataFrame(Counter(ham_corpus).most_common(30))[1])
plt.xticks(rotation='vertical')
plt.show()

# %%
df.head()
# Out:
#    Category                                            Message  \
# 0         0  Go until jurong point, crazy.. Available only ...
# 1         0                      Ok lar... Joking wif u oni...
# 2         1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3         0  U dun say so early hor... U c already then say...
# 4         0  Nah I don't think he goes to usf, he lives aro...
#
#    num-of-character  num-of-words  num-of-sentences  \
# 0               111            24                 2
# 1                29             8                 2
# 2               155            37                 2
# 3                49            13                 1
# 4                61            15                 1
#
#                                     transformed_text
# 0  go jurong point crazi avail bugi n great world...
# 1                              ok lar joke wif u oni
# 2  free entri 2 wkli comp win fa cup final tkt 21...
# 3                u dun say earli hor u c alreadi say
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
cv = CountVectorizer()
tfidf = TfidfVectorizer(max_features=3000)

# %%
X = tfidf.fit_transform(df['transformed_text']).toarray()

# %%
X.shape
# Out:
# (5157, 3000)

# %%
y = df['Category'].values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
from sklearn.naive_bayes import GaussianNB,MultinomialNB,BernoulliNB
from sklearn.metrics import accuracy_score,confusion_matrix,precision_score

# %%
gnb = GaussianNB()
mnb = MultinomialNB()
bnb = BernoulliNB()

# %%
gnb.fit(X_train,y_train)
y_pred1 = gnb.predict(X_test)
print(accuracy_score(y_test,y_pred1))
print(confusion_matrix(y_test,y_pred1))
print(precision_score(y_test,y_pred1))
# Out:
# 0.8672480620155039
# [[786 119]
#  [ 18 109]]
# 0.4780701754385965

# %%
mnb.fit(X_train,y_train)
y_pred2 = mnb.predict(X_test)
print(accuracy_score(y_test,y_pred2))
print(confusion_matrix(y_test,y_pred2))
print(precision_score(y_test,y_pred2))
# Out:
# 0.9718992248062015
# [[905   0]
#  [ 29  98]]
# 1.0

# %%
bnb.fit(X_train,y_train)
y_pred3 = bnb.predict(X_test)
print(accuracy_score(y_test,y_pred3))
print(confusion_matrix(y_test,y_pred3))
# Out:
# 0.9825581395348837
# [[903   2]
#  [ 16 111]]

# %%
import pickle
pickle.dump(tfidf,open('vectorizer.pkl','wb'))
pickle.dump(mnb,open('model.pkl','wb'))
